# %%
from bs4 import BeautifulSoup
import requests as rt
import pandas as pd

# %%
url = 'https://josaa.admissions.nic.in/seatinfo/root/seatmatrixinfo.aspx'
params = {
    #"ctl00$ContentPlaceHolder1$ddlroundno": 
    "ctl00$ContentPlaceHolder1$ddlInstype": "0",
    "ctl00$ContentPlaceHolder1$ddlInstitute": "0",
    "ctl00$ContentPlaceHolder1$ddlBranch": "0",
    "ctl00$ContentPlaceHolder1$btnSubmit": "Submit"
}

# %%
def scrape(Year):   
    with rt.Session() as s:
        R = s.get(url)
        data = {}

        #data.update({tag['name']: tag['value'] for tag in BeautifulSoup(R.content, 'lxml').select('input[name^=__]')})
        #data["ctl00$ContentPlaceHolder1$ddlYear"] = Year
        #R = s.post(url, data=data)

        #data.update({tag['name']: tag['value'] for tag in BeautifulSoup(R.content, 'lxml').select('input[name^=__]')})
        #data["ctl00$ContentPlaceHolder1$ddlroundno"] = Round
        #R = s.post(url, data=data)

        for key, value in params.items():
            data.update({tag['name']: tag['value'] for tag in BeautifulSoup(R.content, 'lxml').select('input[name^=__]')})
            data[key] = value
            R = s.post(url, data=data)
        #print(R.text)
        #print(data)

    table = BeautifulSoup(R.text, 'lxml').find(id = 'GridView1')
    #print(table)
    df = pd.read_html(table.prettify())[0]
    df.dropna(inplace = True, how="all")
    
    df['Year'] = Year
    #df['Round'] = Round
    #df['Opening Rank'] = df['Opening Rank'].astype(int)
    #df['Closing Rank'] = df['Closing Rank'].astype(int)
    
    return df

# %%
df = scrape('2021')
df
# Out:
#                                   Institute Name  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 2102     North-Eastern Hill University, Shillong
# 2103     North-Eastern Hill University, Shillong
# 2104     North-Eastern Hill University, Shillong
# 2105     North-Eastern Hill University, Shillong
# 2106                                         NaN
#
#                                            Program Name State/All India Seats  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...             All India
# 1     Civil Engineering (4 Years, Bachelor of Techno...             All India
# 2     Computer Science and Engineering (4 Years, Bac...             All India
# 3     Computer Science and Engineering (4 Years, Bac...             All India
# 4     Electrical Engineering (4 Years, Bachelor of T...             All India
# ...                                                 ...                   ...
# 2102  Biomedical Engineering (4 Years, Bachelor of T...             All India
# 2103  Biomedical Engineering (4 Years, Bachelor of T...             All India
# 2104  Energy Engineering (4 Years, Bachelor of Techn...             All India
# 2105  Energy Engineering (4 Years, Bachelor of Techn...             All India
# 2106                                                NaN                   NaN
#
#                                   Seat Pool   OPEN  OPEN-PwD  GEN-EWS  \
# 0                            Gender-Neutral     21         0        5
# 1     Female-only (including Supernumerary)      5         0        1
# 2                            Gender-Neutral     22         1        4
# 3     Female-only (including Supernumerary)      5         0        1
# 4                            Gender-Neutral     22         1        6
# ...                                     ...    ...       ...      ...
# 2102                         Gender-Neutral      7         1        2
# 2103  Female-only (including Supernumerary)      0         0        0
# 2104                         Gender-Neutral      7         1        2
# 2105  Female-only (including Supernumerary)      0         0        0
# 2106                            Total Seats  20755      1074     4997
#
#       GEN-EWS-PwD    SC  SC-PwD    ST  ST-PwD  OBC-NCL  OBC-NCL-PwD  \
# 0               0     9       1     3       0       13            1
# 1               0     1       1     1       0        4            0
# 2               0     7       1     4       1       13            1
# 3               0     1       1     1       0        4            1
# 4               0     8       0     4       0       14            1
# ...           ...   ...     ...   ...     ...      ...          ...
# 2102            0     3       0     2       0        5            0
# 2103            0     0       0     0       0        0            0
# 2104            0     3       0     2       0        5            0
# 2105            0     0       0     0       0        0            0
# 2106          261  7330     401  4127     201    12648          659
#
#      Total(includes Female Supernumerary)  \
# 0                                      53
# 1       13  (including "4" Supernumerary)
# 2                                      54
# 3       14  (including "5" Supernumerary)
# 4                                      56
# ...                                   ...
# 2102                                   20
# 2103     0  (including "0" Supernumerary)
# 2104                                   20
# 2105     0  (including "0" Supernumerary)
# 2106                                52453
#
#      Program-Total  Seat Capacity  Female Supernumerary  Year
# 0                                                 62  4  2021
# 1                                                 62  4  2021
# 2                                                 63  5  2021
# 3                                                 63  5  2021
# 4                                                 62  8  2021
# ...                                                 ...   ...
# 2102                                              20  0  2021
# 2103                                              20  0  2021
# 2104                                              20  0  2021
# 2105                                              20  0  2021
# 2106                                        50016  2437  2021
#
# [2107 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['Institute Name', 'Program Name', 'State/All India Seats', 'Seat Pool',
#        'OPEN', 'OPEN-PwD', 'GEN-EWS', 'GEN-EWS-PwD', 'SC', 'SC-PwD', 'ST',
#        'ST-PwD', 'OBC-NCL', 'OBC-NCL-PwD',
#        'Total(includes Female Supernumerary)',
#        'Program-Total  Seat Capacity  Female Supernumerary', 'Year'],
#       dtype='object')
